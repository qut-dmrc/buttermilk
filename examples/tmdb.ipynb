# %%
from buttermilk.utils.nb import nb_init

bm = nb_init(job="tmdb_ids", project="mediamarkets")
# Out:
# 2025-09-22 14:38:53 [info     ] Bootstrapping full application context...
# 2025-09-22 14:38:53 [info     ] Configuration loaded via new Hydra initialization
# 2025-09-22 14:38:53 [debug    ] Configuration loaded           config_keys=['run', 'hydra.job.chdir', 'verbose', 'flows', 'bm', 'infrastructure']
# 2025-09-22 14:38:53 [debug    ] Infrastructure configuration loaded clouds_count=0 has_datasets=False has_logging=False has_secret_provider=False has_tracing=True
# 2025-09-22 14:38:53 [debug    ] No ExecutionContext found, creating new one
# [09/22/2025 02:38:54 PM] INFO     Log file created at /tmp/buttermilk_exec-20250922T0438Z-Fkrh-nicwin-nic.jsonl
#                          INFO     ExecutionContext logging enabled
#                          INFO     ExecutionContext logging initialized
#                          INFO     ExecutionContext synchronous initialization completed
#                          INFO     Initialized ExecutionContext
# ...

# %%
from buttermilk.tools.catalog_test import Observation, Title, TitleType, TMDBTool

tmdb = TMDBTool()
all_movies = await tmdb.get_all_movies(include_adult=True, include_video=False)
# Out:
# Fetching TMDB pages: 500page [10:15,  1.23s/page, movies=1e+4, current_page=500]
# Error in get_all_movies: 400, message='Bad Request', url='https://api.themoviedb.org/3/discover/movie?api_key=7114a93a89607cf6d848aa3f2df39491&language=en-US&region=AU&watch_region=AU&page=501&sort_by=primary_release_date.asc&include_adult=true&include_video=false'

# %%
all_movies
# Out:
# [Title(record_id='315946', title='Passage of Venus', year=1874, type='movie', metadata={'original_title': 'Passage de Venus', 'overview': 'Photo sequence of the rare transit of Venus over the face of the Sun, one of the first chronophotographic sequences.  In 1873, P.J.C. Janssen, or Pierre Jules César Janssen, invented the Photographic Revolver, which captured a series of images in a row. The device, automatic, produced images in a row without human intervention, being used to serve as photographic evidence of the passage of Venus before the Sun, in 1874.', 'poster_path': '/XWPDZzK7N2WQcejI8W96IxZEeP.jpg', 'backdrop_path': '/v6sqKSZQcyN5R7xzVmNVi3t2Kyf.jpg', 'popularity': 0.2717, 'vote_average': 6.4, 'vote_count': 126, 'genre_ids': [99], 'adult': False, 'video': False, 'original_language': 'fr'}),
# ...
