# %%
from buttermilk.utils.nb import nb_init
from buttermilk import logger
from buttermilk.utils.nb import *

# Notebooks
bm = nb_init(job="notebook_description", project="example", config_dir="/src/buttermilk/buttermilk/conf")

# standard plotting libraries are imported and defaults configured
ax = sns.barplot(x=["A", "B", "C"], y=[1, 3, 2])
# Out:
# [09/15/25 10:08:47] INFO     Bootstrapping full application context...
#                     INFO     Configuration loaded via new Hydra initialization
#                     INFO     ExecutionContext created with full infrastructure configuration
#                     INFO     Tracing providers initialized successfully
#                     INFO     Full application context bootstrap complete
#                     INFO     Bootstrapping session context
#                     INFO     Session logging context established
#                     INFO     Session initialized successfully
#                     INFO     Session context bootstrap complete: session-20250915T0008Z-mPR6-nicdev-nic
#                     INFO     Starting notebook run for example job notebook_description
# Notebook graphing defaults applied
